# %% [markdown]
# step-1: import Libraries & Load Dataset

# %%
import pandas as pd

# %%
from sklearn. model_selection import train_test_split

# %%
from sklearn.metrics import accuracy_score

# %%
from sklearn.linear_model import LogisticRegression

# %%
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv("loan_approval_dataset.csv")

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4269 entries, 0 to 4268
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   loan_id                    4269 non-null   int64
#  1    no_of_dependents          4269 non-null   int64
#  2    education                 4269 non-null   str
#  3    self_employed             4269 non-null   str
#  4    income_annum              4269 non-null   int64
#  5    loan_amount               4269 non-null   int64
#  6    loan_term                 4269 non-null   int64
#  7    cibil_score               4269 non-null   int64
#  8    residential_assets_value  4269 non-null   int64
#  9    commercial_assets_value   4269 non-null   int64
#  10   luxury_assets_value       4269 non-null   int64
#  11   bank_asset_value          4269 non-null   int64
#  12   loan_status               4269 non-null   str
# dtypes: int64(10), str(3)
# memory usage: 433.7 KB

# %% [markdown]
# step-2: Data prepocessing

# %%
for i in df :
    print(i)
# Out:
# loan_id
#  no_of_dependents
#  education
#  self_employed
#  income_annum
#  loan_amount
#  loan_term
#  cibil_score
#  residential_assets_value
#  commercial_assets_value
#  luxury_assets_value
#  bank_asset_value
#  loan_status

# %%
df = df [[
    " no_of_dependents",
    " loan_amount",
    " loan_term",
    " income_annum",
    " residential_assets_value",
    " commercial_assets_value",
    " luxury_assets_value",
    " bank_asset_value",
    " cibil_score",
    " loan_status"
]]
# feature selection

# %%
df[' Total_Asset_value'] = df[' residential_assets_value']
+ df[' luxury_assets_value']
+ df[' commercial_assets_value']
+ df[' bank_asset_value']
# feature extraction
# Out:
# 0        8000000
# 1        3300000
# 2       12800000
# 3        7900000
# 4        5000000
#           ...
# 4264      800000
# 4265     1900000
# 4266     7300000
# 4267     5800000
# 4268    12000000
# Name:  bank_asset_value, Length: 4269, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4269 entries, 0 to 4268
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0    no_of_dependents          4269 non-null   int64
#  1    loan_amount               4269 non-null   int64
#  2    loan_term                 4269 non-null   int64
#  3    income_annum              4269 non-null   int64
#  4    residential_assets_value  4269 non-null   int64
#  5    commercial_assets_value   4269 non-null   int64
#  6    luxury_assets_value       4269 non-null   int64
#  7    bank_asset_value          4269 non-null   int64
#  8    cibil_score               4269 non-null   int64
#  9    loan_status               4269 non-null   str
#  10   Total_Asset_value         4269 non-null   int64
# dtypes: int64(10), str(1)
# memory usage: 367.0 KB

# %%
df.head()
# Out:
#    no_of_dependents  loan_amount  loan_term  income_annum  \
# 0                 2     29900000         12       9600000
# 1                 0     12200000          8       4100000
# 2                 3     29700000         20       9100000
# 3                 3     30700000          8       8200000
# 4                 5     24200000         20       9800000
#
#    residential_assets_value  commercial_assets_value  luxury_assets_value  \
# 0                   2400000                 17600000             22700000
# 1                   2700000                  2200000              8800000
# 2                   7100000                  4500000             33300000
# 3                  18200000                  3300000             23300000
# 4                  12400000                  8200000             29400000
#
#    bank_asset_value  cibil_score loan_status  Total_Asset_value
# 0           8000000          778    Approved            2400000
# 1           3300000          417    Rejected            2700000
# 2          12800000          506    Rejected            7100000
# 3           7900000          467    Rejected           18200000
# 4           5000000          382    Rejected           12400000

# %%
df = df [[
    " no_of_dependents",
    " loan_amount",
    " loan_term",
    " income_annum",
    " cibil_score",
    " loan_status",
    " Total_Asset_value"
]]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4269 entries, 0 to 4268
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0    no_of_dependents   4269 non-null   int64
#  1    loan_amount        4269 non-null   int64
#  2    loan_term          4269 non-null   int64
#  3    income_annum       4269 non-null   int64
#  4    cibil_score        4269 non-null   int64
#  5    loan_status        4269 non-null   str
#  6    Total_Asset_value  4269 non-null   int64
# dtypes: int64(6), str(1)
# memory usage: 233.6 KB

# %%
df[" loan_status"].value_counts()
# Out:
#  loan_status
# Approved    2656
# Rejected    1613
# Name: count, dtype: int64

# %%
df[' loan_status'] = df[' loan_status'].str.lower()

# %%
df[' loan_status'] = df[' loan_status'].str.strip()

# %%
df[' loan_status'] = df[' loan_status'].replace({
    "rejected" : 0,
    "approved" : 1
}).astype(int)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4269 entries, 0 to 4268
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0    no_of_dependents   4269 non-null   int64
#  1    loan_amount        4269 non-null   int64
#  2    loan_term          4269 non-null   int64
#  3    income_annum       4269 non-null   int64
#  4    cibil_score        4269 non-null   int64
#  5    loan_status        4269 non-null   int64
#  6    Total_Asset_value  4269 non-null   int64
# dtypes: int64(7)
# memory usage: 233.6 KB
